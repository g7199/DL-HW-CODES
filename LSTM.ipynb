# %% [markdown]
# <a href="https://colab.research.google.com/github/g7199/DL-HW-CODES/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/dl/DLFromScratch2/Chap06-Fancy_RNN
# Out:
# /content/drive/MyDrive/dl/DLFromScratch2/Chap06-Fancy_RNN

# %%
import sys
sys.path.append('..')
from common import config
config.GPU = True
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb
from better_rnnlm import BetterRnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# ------------------------------------------------------------
#                        GPU Mode (cupy)
# ------------------------------------------------------------
#
# | 에폭 1 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 10000.01
# | 에폭 1 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 3713.88
# | 에폭 1 |  반복 41 / 1327 | 시간 10[s] | 퍼플렉서티 1861.07
# | 에폭 1 |  반복 61 / 1327 | 시간 13[s] | 퍼플렉서티 1382.25
# | 에폭 1 |  반복 81 / 1327 | 시간 16[s] | 퍼플렉서티 1039.25
# | 에폭 1 |  반복 101 / 1327 | 시간 19[s] | 퍼플렉서티 882.50
# | 에폭 1 |  반복 121 / 1327 | 시간 23[s] | 퍼플렉서티 778.86
# | 에폭 1 |  반복 141 / 1327 | 시간 26[s] | 퍼플렉서티 731.85
# | 에폭 1 |  반복 161 / 1327 | 시간 29[s] | 퍼플렉서티 683.33
# | 에폭 1 |  반복 181 / 1327 | 시간 32[s] | 퍼플렉서티 681.43
# | 에폭 1 |  반복 201 / 1327 | 시간 35[s] | 퍼플렉서티 604.17
# | 에폭 1 |  반복 221 / 1327 | 시간 39[s] | 퍼플렉서티 580.89
# | 에폭 1 |  반복 241 / 1327 | 시간 42[s] | 퍼플렉서티 518.64
# | 에폭 1 |  반복 261 / 1327 | 시간 45[s] | 퍼플렉서티 536.43
# | 에폭 1 |  반복 281 / 1327 | 시간 49[s] | 퍼플렉서티 528.06
# | 에폭 1 |  반복 301 / 1327 | 시간 52[s] | 퍼플렉서티 452.52
# ...
